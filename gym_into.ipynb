# %% [markdown]
# <a href="https://colab.research.google.com/github/ulat/HTL_TdoT_RL/blob/master/gym_into.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym
# Out:
# Collecting gym
#   Downloading https://files.pythonhosted.org/packages/9b/50/ed4a03d2be47ffd043be2ee514f329ce45d98a30fe2d1b9c61dea5a9d861/gym-0.10.5.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 5.4MB/s
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.14.5)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.11.0)
# Collecting pyglet>=1.2.0 (from gym)
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
#     100% |████████████████████████████████| 1.0MB 11.5MB/s
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2018.4.16)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Building wheels for collected packages: gym
# done
#   Stored in directory: /content/.cache/pip/wheels/cb/14/71/f4ab006b1e6ff75c2b54985c2f98d0644fffe9c1dddc670925
# Successfully built gym
# Installing collected packages: pyglet, gym
# Successfully installed gym-0.10.5 pyglet-1.3.2

# %%
# !apt-get install python-opengl -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libelf1 libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libglu1-mesa libllvm5.0 libpciaccess0 libsensors4 libtxc-dxtn-s2tc
#   libx11-xcb1 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-sync1 libxdamage1 libxfixes3 libxi6 libxshmfence1 libxxf86vm1
# Suggested packages:
#   pciutils lm-sensors python-numpy libgle3
# The following NEW packages will be installed:
#   freeglut3 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libelf1 libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libglu1-mesa libllvm5.0 libpciaccess0 libsensors4 libtxc-dxtn-s2tc
#   libx11-xcb1 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-sync1 libxdamage1 libxfixes3 libxi6 libxshmfence1 libxxf86vm1
#   python-opengl
# 0 upgraded, 28 newly installed, 0 to remove and 6 not upgraded.
# Need to get 20.7 MB of archives.
# After this operation, 194 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 libxshmfence1 amd64 1.2-1 [5,042 B]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 libelf1 amd64 0.170-0.1 [44.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-common all 2.4.83-1 [4,938 B]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm2 amd64 2.4.83-1 [30.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libglapi-mesa amd64 17.2.8-0ubuntu0~17.10.1 [22.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libx11-xcb1 amd64 2:1.6.4-3 [9,626 B]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri2-0 amd64 1.12-1ubuntu1 [6,838 B]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri3-0 amd64 1.12-1ubuntu1 [5,156 B]
# Get:10 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-glx0 amd64 1.12-1ubuntu1 [22.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-present0 amd64 1.12-1ubuntu1 [5,436 B]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-sync1 amd64 1.12-1ubuntu1 [8,746 B]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-amdgpu1 amd64 2.4.83-1 [18.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 libpciaccess0 amd64 0.13.4-1ubuntu1 [17.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-intel1 amd64 2.4.83-1 [59.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-nouveau2 amd64 2.4.83-1 [16.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-radeon1 amd64 2.4.83-1 [21.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful/main amd64 libllvm5.0 amd64 1:5.0-3 [13.7 MB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-dri amd64 17.2.8-0ubuntu0~17.10.1 [5,707 kB]
# Get:23 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-glx amd64 17.2.8-0ubuntu0~17.10.1 [130 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu artful/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/main amd64 libglu1-mesa amd64 9.0.0-2.1build1 [168 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/main amd64 libtxc-dxtn-s2tc amd64 1.0+git20151227-2 [48.4 kB]
# Fetched 20.7 MB in 1s (13.1 MB/s)
# Selecting previously unselected package libxshmfence1:amd64.
# (Reading database ... 18396 files and directories currently installed.)
# Preparing to unpack .../00-libxshmfence1_1.2-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.2-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../01-libxxf86vm1_1%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1) ...
# Selecting previously unselected package libelf1:amd64.
# Preparing to unpack .../02-libelf1_0.170-0.1_amd64.deb ...
# Unpacking libelf1:amd64 (0.170-0.1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../03-libdrm-common_2.4.83-1_all.deb ...
# Unpacking libdrm-common (2.4.83-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../04-libdrm2_2.4.83-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.83-1) ...
# Selecting previously unselected package libglapi-mesa:amd64.
# Preparing to unpack .../05-libglapi-mesa_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../06-libx11-xcb1_2%3a1.6.4-3_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.4-3) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../07-libxcb-dri2-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../08-libxcb-dri3-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-glx0:amd64.
# Preparing to unpack .../09-libxcb-glx0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-glx0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../10-libxcb-present0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../11-libxcb-sync1_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxdamage1:amd64.
# Preparing to unpack .../12-libxdamage1_1%3a1.1.4-3_amd64.deb ...
# Unpacking libxdamage1:amd64 (1:1.1.4-3) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../13-libxfixes3_1%3a5.0.3-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../14-libdrm-amdgpu1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libpciaccess0:amd64.
# Preparing to unpack .../15-libpciaccess0_0.13.4-1ubuntu1_amd64.deb ...
# Unpacking libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Selecting previously unselected package libdrm-intel1:amd64.
# Preparing to unpack .../16-libdrm-intel1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libdrm-nouveau2:amd64.
# Preparing to unpack .../17-libdrm-nouveau2_2.4.83-1_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.83-1) ...
# Selecting previously unselected package libdrm-radeon1:amd64.
# Preparing to unpack .../18-libdrm-radeon1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libllvm5.0:amd64.
# Preparing to unpack .../19-libllvm5.0_1%3a5.0-3_amd64.deb ...
# Unpacking libllvm5.0:amd64 (1:5.0-3) ...
# Selecting previously unselected package libsensors4:amd64.
# Preparing to unpack .../20-libsensors4_1%3a3.4.0-4_amd64.deb ...
# Unpacking libsensors4:amd64 (1:3.4.0-4) ...
# Selecting previously unselected package libgl1-mesa-dri:amd64.
# Preparing to unpack .../21-libgl1-mesa-dri_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../22-libgl1-mesa-glx_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../23-libxi6_2%3a1.7.9-1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.7.9-1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../24-freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../25-libglu1-mesa_9.0.0-2.1build1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../26-python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package libtxc-dxtn-s2tc:amd64.
# Preparing to unpack .../27-libtxc-dxtn-s2tc_1.0+git20151227-2_amd64.deb ...
# Unpacking libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# Setting up libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-glx0:amd64 (1.12-1ubuntu1) ...
# Setting up libxdamage1:amd64 (1:1.1.4-3) ...
# Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# Setting up libelf1:amd64 (0.170-0.1) ...
# Setting up libxshmfence1:amd64 (1.2-1) ...
# Setting up libllvm5.0:amd64 (1:5.0-3) ...
# Setting up libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/s2tc/libtxc_dxtn.so to provide /usr/lib/x86_64-linux-gnu/libtxc_dxtn.so (libtxc-dxtn-x86_64-linux-gnu) in auto mode
# Setting up libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libdrm-common (2.4.83-1) ...
# Setting up libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Setting up libx11-xcb1:amd64 (2:1.6.4-3) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up libdrm2:amd64 (2.4.83-1) ...
# Setting up libdrm-intel1:amd64 (2.4.83-1) ...
# Setting up libdrm-radeon1:amd64 (2.4.83-1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.83-1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Setting up libgl1-mesa-dri:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libgl1-mesa-glx:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# Setting up libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...

# %%
# !apt install xvfb -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libpixman-1-0 libxaw7 libxfont1 libxfont2 libxkbfile1 libxmu6
#   libxmuu1 libxpm4 libxt6 x11-xkb-utils xauth xfonts-base xfonts-encodings
#   xfonts-utils xkb-data xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libpixman-1-0 libxaw7 libxfont1 libxfont2 libxkbfile1 libxmu6
#   libxmuu1 libxpm4 libxt6 x11-xkb-utils xauth xfonts-base xfonts-encodings
#   xfonts-utils xkb-data xserver-common xvfb
# 0 upgraded, 18 newly installed, 0 to remove and 6 not upgraded.
# Need to get 8,782 kB of archives.
# After this operation, 17.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 xkb-data all 2.19-1.1ubuntu1 [312 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 xauth amd64 1:1.0.9-1ubuntu2 [22.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-0 amd64 0.34.0-1 [230 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmu6 amd64 2:1.1.2-2 [46.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libxpm4 amd64 1:3.5.12-1 [34.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libxaw7 amd64 2:1.0.13-1 [173 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxfont1 amd64 1:1.5.2-4ubuntu1.1 [94.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxfont2 amd64 1:2.0.1-3ubuntu1.1 [91.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbfile1 amd64 1:1.0.9-2 [64.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 x11-xkb-utils amd64 7.7+3 [158 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-utils amd64 1:7.7+4 [75.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 xserver-common all 2:1.19.5-0ubuntu2 [26.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/universe amd64 xvfb amd64 2:1.19.5-0ubuntu2 [783 kB]
# Fetched 8,782 kB in 1s (7,308 kB/s)
#
# 78Selecting previously unselected package xkb-data.
# (Reading database ... 20926 files and directories currently installed.)
# Preparing to unpack .../00-xkb-data_2.19-1.1ubuntu1_all.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  1%] [..........................................................] 8Unpacking xkb-data (2.19-1.1ubuntu1) ...
# 7Progress: [  2%] [#.........................................................] 87Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../01-libxmuu1_2%3a1.1.2-2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libxmuu1:amd64 (2:1.1.2-2) ...
# 7Progress: [  5%] [###.......................................................] 87Progress: [  6%] [###.......................................................] 8Selecting previously unselected package xauth.
# Preparing to unpack .../02-xauth_1%3a1.0.9-1ubuntu2_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking xauth (1:1.0.9-1ubuntu2) ...
# 7Progress: [  8%] [#####.....................................................] 87Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../03-libfontenc1_1%3a1.1.3-1_amd64.deb ...
# 7Progress: [ 10%] [######....................................................] 8Unpacking libfontenc1:amd64 (1:1.1.3-1) ...
# 7Progress: [ 12%] [#######...................................................] 87Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../04-libpixman-1-0_0.34.0-1_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libpixman-1-0:amd64 (0.34.0-1) ...
# 7Progress: [ 15%] [########..................................................] 87Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../05-libxt6_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 17%] [##########................................................] 8Unpacking libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxmu6:amd64.
# Preparing to unpack .../06-libxmu6_2%3a1.1.2-2_amd64.deb ...
# 7Progress: [ 20%] [############..............................................] 8Unpacking libxmu6:amd64 (2:1.1.2-2) ...
# 7Progress: [ 21%] [############..............................................] 87Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libxpm4:amd64.
# Preparing to unpack .../07-libxpm4_1%3a3.5.12-1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 25%] [##############............................................] 87Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libxaw7:amd64.
# Preparing to unpack .../08-libxaw7_2%3a1.0.13-1_amd64.deb ...
# 7Progress: [ 27%] [###############...........................................] 8Unpacking libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 28%] [################..........................................] 87Progress: [ 29%] [#################.........................................] 8
# Selecting previously unselected package libxfont1:amd64.
# Preparing to unpack .../09-libxfont1_1%3a1.5.2-4ubuntu1.1_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libxfont1:amd64 (1:1.5.2-4ubuntu1.1) ...
# 7Progress: [ 31%] [##################........................................] 87Progress: [ 32%] [###################.......................................] 8Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../10-libxfont2_1%3a2.0.1-3ubuntu1.1_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libxfont2:amd64 (1:2.0.1-3ubuntu1.1) ...
# 7Progress: [ 35%] [####################......................................] 87Progress: [ 36%] [#####################.....................................] 8Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../11-libxkbfile1_1%3a1.0.9-2_amd64.deb ...
# 7Progress: [ 37%] [#####################.....................................] 8Unpacking libxkbfile1:amd64 (1:1.0.9-2) ...
# 7Progress: [ 38%] [######################....................................] 87Progress: [ 39%] [######################....................................] 8Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../12-x11-xkb-utils_7.7+3_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking x11-xkb-utils (7.7+3) ...
# 7Progress: [ 41%] [########################..................................] 87Progress: [ 42%] [########################..................................] 8Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../13-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking xfonts-encodings (1:1.0.4-2) ...
# 7Progress: [ 45%] [##########################................................] 87Progress: [ 46%] [##########################................................] 8Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../14-xfonts-utils_1%3a7.7+4_amd64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking xfonts-utils (1:7.7+4) ...
# 7Progress: [ 48%] [############################..............................] 87Progress: [ 49%] [############################..............................] 8Selecting previously unselected package xfonts-base.
# Preparing to unpack .../15-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking xfonts-base (1:1.0.4+nmu1) ...
# 7Progress: [ 51%] [#############################.............................] 87Progress: [ 52%] [##############################............................] 8Selecting previously unselected package xserver-common.
# Preparing to unpack .../16-xserver-common_2%3a1.19.5-0ubuntu2_all.deb ...
# 7Progress: [ 53%] [###############################...........................] 8Unpacking xserver-common (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 54%] [###############################...........................] 87Progress: [ 56%] [################################..........................] 8Selecting previously unselected package xvfb.
# Preparing to unpack .../17-xvfb_2%3a1.19.5-0ubuntu2_amd64.deb ...
# 7Progress: [ 57%] [#################################.........................] 8Unpacking xvfb (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 58%] [#################################.........................] 87Progress: [ 59%] [##################################........................] 8Setting up libxkbfile1:amd64 (1:1.0.9-2) ...
# 7Progress: [ 60%] [###################################.......................] 87Progress: [ 61%] [###################################.......................] 8Setting up xkb-data (2.19-1.1ubuntu1) ...
# 7Progress: [ 62%] [####################################......................] 87Progress: [ 63%] [####################################......................] 8Setting up xfonts-encodings (1:1.0.4-2) ...
# 7Progress: [ 64%] [#####################################.....................] 87Progress: [ 65%] [######################################....................] 8Setting up libxmuu1:amd64 (2:1.1.2-2) ...
# 7Progress: [ 67%] [######################################....................] 87Progress: [ 68%] [#######################################...................] 8Setting up xauth (1:1.0.9-1ubuntu2) ...
# 7Progress: [ 69%] [########################################..................] 87Progress: [ 70%] [########################################..................] 8Setting up libpixman-1-0:amd64 (0.34.0-1) ...
# 7Progress: [ 71%] [#########################################.................] 87Progress: [ 72%] [##########################################................] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# 7Progress: [ 73%] [##########################################................] 87Progress: [ 74%] [###########################################...............] 8Setting up libxpm4:amd64 (1:3.5.12-1) ...
# 7Progress: [ 75%] [###########################################...............] 87Progress: [ 76%] [############################################..............] 8Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 78%] [#############################################.............] 87Progress: [ 79%] [#############################################.............] 8Setting up libxfont2:amd64 (1:2.0.1-3ubuntu1.1) ...
# 7Progress: [ 80%] [##############################################............] 87Progress: [ 81%] [###############################################...........] 8Setting up libxfont1:amd64 (1:1.5.2-4ubuntu1.1) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 83%] [################################################..........] 8Setting up libxmu6:amd64 (2:1.1.2-2) ...
# 7Progress: [ 84%] [#################################################.........] 87Progress: [ 85%] [#################################################.........] 8Setting up libxaw7:amd64 (2:1.0.13-1) ...
# 7Progress: [ 86%] [##################################################........] 87Progress: [ 87%] [##################################################........] 8Setting up x11-xkb-utils (7.7+3) ...
# 7Progress: [ 89%] [###################################################.......] 87Progress: [ 90%] [####################################################......] 8Setting up xfonts-utils (1:7.7+4) ...
# 7Progress: [ 91%] [####################################################......] 87Progress: [ 92%] [#####################################################.....] 8Setting up xfonts-base (1:1.0.4+nmu1) ...
# 7Progress: [ 93%] [######################################################....] 87Progress: [ 94%] [######################################################....] 8Setting up xserver-common (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 95%] [#######################################################...] 87Progress: [ 96%] [########################################################..] 8Setting up xvfb (2:1.19.5-0ubuntu2) ...
# 7Progress: [ 97%] [########################################################..] 87Progress: [ 98%] [#########################################################.] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
#
# 78

# %%
# !pip install pyvirtualdisplay
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/39/37/f285403a09cc261c56b6574baace1bdcf4b8c7428c8a7239cbba137bc0eb/PyVirtualDisplay-0.2.1.tar.gz
# Collecting EasyProcess (from pyvirtualdisplay)
#   Downloading https://files.pythonhosted.org/packages/0d/f1/d2de7591e7dfc164d286fa16f051e6c0cf3141825586c3b04ae7cda7ac0f/EasyProcess-0.2.3.tar.gz
# Building wheels for collected packages: pyvirtualdisplay, EasyProcess
# done
#   Stored in directory: /content/.cache/pip/wheels/d1/8c/16/1c64227974ae29c687e4cc30fd691d5c0fd40f54446dde99da
# done
#   Stored in directory: /content/.cache/pip/wheels/b4/c6/e3/c163b04029d8fccfd54b809802640c1af587a01be8d7a04e1a
# Successfully built pyvirtualdisplay EasyProcess
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.2.3 pyvirtualdisplay-0.2.1

# %%
# !pip install piglet
# Out:
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/86/f6/ef278239ebe525466ea51a7dd9d6d3211d197ac4b4abc76e17cdd419f69c/piglet-0.4.4.tar.gz (52kB)
#     100% |████████████████████████████████| 61kB 2.2MB/s
# Collecting Parsley (from piglet)
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 4.6MB/s
# Collecting attrs (from piglet)
#   Downloading https://files.pythonhosted.org/packages/41/59/cedf87e91ed541be7957c501a92102f9cc6363c623a7666d69d51c78ac5b/attrs-18.1.0-py2.py3-none-any.whl
# Collecting astunparse (from piglet)
#   Downloading https://files.pythonhosted.org/packages/8b/ea/d38686f1718e307d83673d905dcffd142640a31a217e4e76d1de78f21b20/astunparse-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet) (1.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (1.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet) (0.31.1)
# Building wheels for collected packages: piglet
# done
#   Stored in directory: /content/.cache/pip/wheels/c7/59/a5/5bd1a35a4a4596714c4c7925a1751e7b1580b6ced363fd7969
# Successfully built piglet
# Installing collected packages: Parsley, attrs, astunparse, piglet
# Successfully installed Parsley-1.3 astunparse-1.5.0 attrs-18.1.0 piglet-0.4.4

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %% [markdown]
# **OpenAI Gym**
#
# We're gonna spend several next weeks learning algorithms that solve decision processes. We are then in need of some interesting decision problems to test our algorithms.
#
# That's where OpenAI gym comes into play. It's a python library that wraps many classical decision problems including robot control, videogames and board games.
#
# So here's how it works:

# %%
import gym
env = gym.make("MountainCar-v0")

plt.imshow(env.render('rgb_array'))
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation space: Box(2,)
# Action space: Discrete(3)

# %% [markdown]
# reset() - reset environment to initial state, return first observation
#
# render() - show current environment state (a more colorful version :) )
#
# step(a) - commit action a and return (new observation, reward, is done, info)

# %%
obs0 = env.reset()
print("initial observation code:", obs0)

# Note: in MountainCar, observation is just two numbers: car position and velocity
# Out:
# initial observation code: [-0.56157244  0.        ]

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(2)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-0.56028825  0.00128419]
# reward: -1.0
# is game over?: False

# %% [markdown]
# # Time to play
#
# Try tweaking t or action strategy
#
# **Remember**: Target is to reach to flag

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

def policy(t):
    if t>50 and t<100:
        return actions['left']
    else:
        return actions['right']


for t in range(TIME_LIMIT):
    
    # change the line below to reach the flag
    s, r, done, _ = env.step(policy(t))
    
    #draw game image on display
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <div id='75b80cce-9be8-4a08-92a3-6018fc6775a7'></div>
# Well done!
# <div id='a1ef82a0-24c5-40df-8972-a92903713d38'></div>
